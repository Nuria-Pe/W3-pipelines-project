# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ls
# Out:
# DATA/           README.md       Untitled.ipynb  df.csv

# %%
data = pd.read_csv('data/all_seasons.csv', encoding='cp1252')

# %%
data
# Out:
#        Unnamed: 0         player_name team_abbreviation   age  player_height  \
# 0               0       Dennis Rodman               CHI  36.0         198.12
# 1               1   Dwayne Schintzius               LAC  28.0         215.90
# 2               2        Earl Cureton               TOR  39.0         205.74
# 3               3         Ed O'Bannon               DAL  24.0         203.20
# 4               4         Ed Pinckney               MIA  34.0         205.74
# ...           ...                 ...               ...   ...            ...
# 11140       11140         Maxi Kleber               DAL  28.0         208.28
# 11141       11141  Melvin Frazier Jr.               ORL  23.0         195.58
# 11142       11142      Meyers Leonard               MIA  28.0         213.36
# 11143       11143        Norvel Pelle               PHI  27.0         208.28
# 11144       11144         Matt Thomas               TOR  25.0         193.04
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11145 entries, 0 to 11144
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         11145 non-null  int64
#  1   player_name        11145 non-null  object
#  2   team_abbreviation  11145 non-null  object
#  3   age                11145 non-null  float64
#  4   player_height      11145 non-null  float64
#  5   player_weight      11145 non-null  float64
#  6   college            11145 non-null  object
#  7   country            11145 non-null  object
#  8   draft_year         11145 non-null  object
#  9   draft_round        11145 non-null  object
#  10  draft_number       11145 non-null  object
#  11  gp                 11145 non-null  int64
#  12  pts                11145 non-null  float64
#  13  reb                11145 non-null  float64
#  14  ast                11145 non-null  float64
#  15  net_rating         11145 non-null  float64
# ...

# %%
set(data.player_name)
# Out:
# {'Garth Joseph',
#  'Antonio Harvey',
#  'Maurice Ndour',
#  'Tim James',
#  'Bernard Robinson',
#  'Kobi Simmons',
#  'David Noel',
#  'Malcolm Miller',
#  'John Starks',
#  'Clint Capela',
#  'Glenn Robinson',
#  'Mickell Gladness',
#  'Jacob Pullen',
#  'Wang Zhi-zhi',
#  'Rashad Vaughn',
#  'Paul Millsap',
#  'Andrew Harrison',
#  'Jerel McNeal',
#  'Joe Chealey',
#  'Tierre Brown',
#  'Malik Allen',
#  'Ryan Hollins',
#  'Julyan Stone',
#  'JJ Hickson',
#  'Landry Shamet',
#  'Elden Campbell',
#  'Kobe Bryant',
#  'Lonnie Walker IV',
#  "Amar'e Stoudemire",
#  'Jamel Thomas',
#  'Andre Iguodala',
#  'Monta Ellis',
#  'Ersan Ilyasova',
#  'Lester Hudson',
#  'Steve Blake',
#  'Mitchell Robinson',
#  'Cody Martin',
#  'Mario West',
#  'Norvel Pelle',
#  'Mike Batiste',
#  'Mike Conley',
#  'Walt Williams',
#  'Tyler Davis',
#  'Cory Higgins',
#  'Manny Harris',
#  'P.J. Brown',
#  'Shane Battier',
#  'Chase Budinger',
#  'Jermareo Davidson',
#  'Jamal Robinson',
#  'Ja Morant',
# ...

# %%
data_1 = data.drop(['Unnamed: 0', 'net_rating', 'oreb_pct', 'usg_pct', 'dreb_pct', 'ts_pct', 'ast_pct', 'season', 'draft_year', 'draft_round', 'draft_number'], axis = 1)
data_1
# Out:
#               player_name team_abbreviation   age  player_height  \
# 0           Dennis Rodman               CHI  36.0         198.12
# 1       Dwayne Schintzius               LAC  28.0         215.90
# 2            Earl Cureton               TOR  39.0         205.74
# 3             Ed O'Bannon               DAL  24.0         203.20
# 4             Ed Pinckney               MIA  34.0         205.74
# ...                   ...               ...   ...            ...
# 11140         Maxi Kleber               DAL  28.0         208.28
# 11141  Melvin Frazier Jr.               ORL  23.0         195.58
# 11142      Meyers Leonard               MIA  28.0         213.36
# 11143        Norvel Pelle               PHI  27.0         208.28
# 11144         Matt Thomas               TOR  25.0         193.04
#
#        player_weight                      college  country  gp  pts   reb  ast
# 0          99.790240  Southeastern Oklahoma State      USA  55  5.7  16.1  3.1
# ...

# %%
data_1.rename(columns = {'player_name': 'NAME'}, inplace = True)
data_1.rename(columns = {'age': 'AGE'}, inplace = True)
data_1.rename(columns = {'team_abbreviation': 'TEAM'}, inplace = True)
data_1.rename(columns = {'country': 'COUNTRY'}, inplace = True)
data_1.rename(columns = {'college': 'COLLEGE'}, inplace = True)
data_1
# Out:
#                      NAME TEAM   AGE  player_height  player_weight  \
# 0           Dennis Rodman  CHI  36.0         198.12      99.790240
# 1       Dwayne Schintzius  LAC  28.0         215.90     117.933920
# 2            Earl Cureton  TOR  39.0         205.74      95.254320
# 3             Ed O'Bannon  DAL  24.0         203.20     100.697424
# 4             Ed Pinckney  MIA  34.0         205.74     108.862080
# ...                   ...  ...   ...            ...            ...
# 11140         Maxi Kleber  DAL  28.0         208.28     108.862080
# 11141  Melvin Frazier Jr.  ORL  23.0         195.58      97.522280
# 11142      Meyers Leonard  MIA  28.0         213.36     117.933920
# 11143        Norvel Pelle  PHI  27.0         208.28     104.779752
# 11144         Matt Thomas  TOR  25.0         193.04      86.182480
#
#                            COLLEGE  COUNTRY  gp  pts   reb  ast
# 0      Southeastern Oklahoma State      USA  55  5.7  16.1  3.1
# ...

# %%
data_1.AGE.mean()
# Out:
# 27.168685509196948

# %%
data_1.groupby('TEAM').mean()
# Out:
#             AGE  player_height  player_weight         gp       pts       reb  \
# TEAM
# ATL   26.903394     201.170653     101.141541  50.300261  7.703655  3.461619
# BKN   26.700000     200.569286      99.948997  48.614286  8.122857  3.392857
# BOS   26.651226     199.960981     101.029893  53.670300  8.206540  3.519346
# CHA   26.299213     200.325669     100.359027  51.724409  7.900394  3.522441
# CHH   29.056180     200.916854     102.037814  51.617978  7.883146  3.512360
# CHI   26.810298     200.391545      99.753363  52.986450  8.098916  3.632520
# CLE   26.953846     200.920513     101.740686  51.105128  7.878205  3.565128
# DAL   28.250000     201.261927     100.156421  51.625000  8.126042  3.515104
# DEN   26.569892     200.447796      99.736240  52.338710  8.382527  3.681720
# DET   27.497207     200.184637      99.989162  54.368715  7.944972  3.439385
# GSW   26.789894     200.710000     100.232865  51.460106  8.592021  3.770479
# ...

# %%
data_1.groupby('TEAM').AGE.max()
# Out:
# TEAM
# ATL    43.0
# BKN    38.0
# BOS    39.0
# CHA    37.0
# CHH    39.0
# CHI    43.0
# CLE    38.0
# DAL    44.0
# DEN    38.0
# DET    39.0
# GSW    39.0
# HOU    43.0
# IND    40.0
# LAC    40.0
# LAL    40.0
# MEM    40.0
# MIA    40.0
# MIL    40.0
# MIN    40.0
# NJN    40.0
# NOH    36.0
# NOK    36.0
# NOP    36.0
# NYK    41.0
# OKC    39.0
# ORL    40.0
# PHI    40.0
# PHX    39.0
# POR    39.0
# SAC    41.0
# SAS    41.0
# SEA    38.0
# TOR    40.0
# UTA    41.0
# VAN    38.0
# WAS    40.0
# Name: AGE, dtype: float64

# %%
sns.countplot(x = data_1.NAME)
# Out:
# <AxesSubplot:xlabel='NAME', ylabel='count'>

# %%
data_1.to_csv('data_1.csv')
