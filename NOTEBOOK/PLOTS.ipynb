# %%
import seaborn as sns

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_2 = pd.read_csv ('data_1.csv')
data_2
# Out:
#        Unnamed: 0                NAME TEAM   AGE  player_height  \
# 0               0       Dennis Rodman  CHI  36.0         198.12
# 1               1   Dwayne Schintzius  LAC  28.0         215.90
# 2               2        Earl Cureton  TOR  39.0         205.74
# 3               3         Ed O'Bannon  DAL  24.0         203.20
# 4               4         Ed Pinckney  MIA  34.0         205.74
# ...           ...                 ...  ...   ...            ...
# 11140       11140         Maxi Kleber  DAL  28.0         208.28
# 11141       11141  Melvin Frazier Jr.  ORL  23.0         195.58
# 11142       11142      Meyers Leonard  MIA  28.0         213.36
# 11143       11143        Norvel Pelle  PHI  27.0         208.28
# 11144       11144         Matt Thomas  TOR  25.0         193.04
#
#        player_weight                      COLLEGE  COUNTRY  gp  pts   reb  ast
# 0          99.790240  Southeastern Oklahoma State      USA  55  5.7  16.1  3.1
# ...

# %%
sns.set(rc={'figure.figsize':(10,7)})

# %%
sns.countplot(x = data_2.AGE)
sns.set(rc={'figure.figsize':(25,20)})
fig.figure.savefig('players_age.png')

# %%
data_2.head()
# Out:
#    Unnamed: 0               NAME TEAM   AGE  player_height  player_weight  \
# 0           0      Dennis Rodman  CHI  36.0         198.12      99.790240
# 1           1  Dwayne Schintzius  LAC  28.0         215.90     117.933920
# 2           2       Earl Cureton  TOR  39.0         205.74      95.254320
# 3           3        Ed O'Bannon  DAL  24.0         203.20     100.697424
# 4           4        Ed Pinckney  MIA  34.0         205.74     108.862080
#
#                        COLLEGE COUNTRY  gp  pts   reb  ast
# 0  Southeastern Oklahoma State     USA  55  5.7  16.1  3.1
# 1                      Florida     USA  15  2.3   1.5  0.3
# 2                Detroit Mercy     USA   9  0.8   1.0  0.4
# 3                         UCLA     USA  64  3.7   2.3  0.6
# 4                    Villanova     USA  27  2.4   2.4  0.2

# %%
grouped = data_2.groupby('TEAM')['pts'].mean()
fig = grouped.sort_values(ascending = False).plot.bar()
fig.figure.savefig('mean_team_pts.png')

# %%
grouped = data_2.groupby('TEAM')['pts'].max()
fig_2 = grouped.sort_values(ascending = False).plot.bar()
fig.figure.savefig('max_team_pts')
